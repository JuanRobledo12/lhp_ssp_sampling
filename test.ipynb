# %%
import pandas as pd

# %%
df = pd.read_csv('opt_output/optimization_log_test.csv')
df.head()
# Out:
#             MSE   scale_0   scale_1   scale_2   scale_3   scale_4   scale_5  \
# 0  7.727818e+02  1.194029  1.243639  1.545904  1.158478  1.507564  0.501510
# 1  3.635573e+07  1.570574  1.719222  1.468662  1.727629  0.944719  0.487940
# 2  1.100033e+03  1.213593  1.892126  0.412587  1.599398  0.201016  0.544565
# 3  8.636579e+03  1.346373  1.628728  0.825305  0.125598  1.957011  0.650293
# 4  4.236605e+02  1.207239  0.807885  0.758273  0.345939  1.145169  1.392730
#
#     scale_6   scale_7   scale_8  ...  scale_2023  scale_2024  scale_2025  \
# 0  1.279662  0.720054  0.487736  ...    0.174128    1.228620    0.762508
# 1  0.736177  1.484601  0.621295  ...    1.160056    1.439671    0.490359
# 2  1.775072  1.504028  0.586883  ...    1.418209    0.141684    0.278651
# 3  1.790906  0.193468  0.154106  ...    0.340162    1.516924    0.136307
# 4  1.516803  0.757696  1.460057  ...    1.776677    0.838069    0.608866
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Columns: 2034 entries, MSE to scale_2032
# dtypes: float64(2034)
# memory usage: 842.3 KB

# %%
df.MSE.min()
# Out:
# 80.72789870590726
